# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from math import log10,exp
import matplotlib.pyplot as plt
from statsmodels.api import OLS
from scipy.stats import chisquare
import datetime
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")
pd.options.display.max_columns = None

# %%
df1=pd.read_csv('temp_datalab_records_social_facebook.xls')
counts=df1.groupby('username').agg({'talking_about_count':np.std}).sort_values(by='talking_about_count',ascending=False)

# %%
top10=counts[:10]

# %%
plt.rcParams.update({'font.size': 22})
fig, ax = plt.subplots(figsize=(20, 10))  
width = 0.75

y=top10['talking_about_count'].values
x=top10.index.tolist()
ind = np.arange(len(y))  
ax.barh(ind, y, width, color="blue")
ax.set_yticks(ind+width/2)
ax.set_yticklabels(x, minor=False)
plt.title('top 10 volatility of “talking about count”')
plt.xlabel('volatility')
plt.ylabel('companies')      
plt.show()
