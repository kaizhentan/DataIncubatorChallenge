# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
from math import log10,exp
import matplotlib.pyplot as plt
from statsmodels.api import OLS
from scipy.stats import chisquare
import datetime
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")
pd.options.display.max_columns = None

# %%
df1=pd.read_csv('temp_datalab_records_social_facebook.xls')

# %%
df1.groupby('username').agg({'checkins':np.sum}).sort_values(by='checkins',ascending=False)
# Out:
#                              checkins
# username
# Disneyland                 7966491074
# WaltDisneyWorld            3057713075
# KnottsBerryFarm            2400647362
# SeaWorld                   2346420768
# TheGarden                  2139298637
# DisneylandParisfr          2028963568
# BuschGardensTampaBay       1817112592
# cedarpoint                 1323897601
# empirestatebuilding        1304477805
# wynnlasvegas                959992611
# MadisonSquareGarden         892183109
# CanadasWonderland           880165319
# cagreatamerica              812053399
# carowindspark               753665016
# BuschGardensVA              726132806
# visitkingsisland            676791690
# kingsdominionva             632015679
# dorneypark                  585810954
# cityofdreamsmanila          582430634
# grandoleopry                560275029
# disneyland.hk               549197462
# Breckenridge                520312217
# BorgataAC                   448866981
# aquaticaorlando             404735823
# WorldsofFun                 401743338
# Keystone                    401701224
# orleanscasino               397524134
# Google                      397131378
# TheRymanAuditorium          359796423
# vailmtn                     350307285
# ...                               ...
# daz                                 0
# daytimer                            0
# dawn                                0
# LauraScuddersPeanutButter           0
# daveandbusters                      0
# Lawn.Boy.Mowers                     0
# LeMarsInsurance                     0
# LeeRiders                           0
# LeggsBrand                          0
# LehighCustomFit                     0
# LeicaBiosystems                     0
# LendingTree                         0
# Lennar                              0
# LexarMemory                         0
# Lexarphotography                    0
# daVinciSurgery                      0
# LibertyHardware                     0
# cynthiarowleyny                     0
# LifeLock                            0
# cw39houston                         0
# LifeTime.Life                       0
# LifeVantage                         0
# Lifetime.Life                       0
# ctripcom                            0
# ctrip.en                            0
# LincolnElectric                     0
# LiquidPlumr                         0
# ListHub                             0
# LitterGenie                         0
# haincelestialcanada                 0
#
# [4950 rows x 1 columns]
